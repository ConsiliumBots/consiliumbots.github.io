# %% [markdown]
# # Dashboard Republica Dominicana

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import scipy, random, copy, h5py, math, csv, sys, os, pickle, re, json, warnings
import matplotlib.pyplot as plt
from itertools import combinations
from numpy.random import RandomState
from datetime import datetime

# Path
path = os.getcwd()
sub_routines = os.path.join(path,'..','explorador-brain','brain', 'dashboard')
sys.path.append(sub_routines)
# import dashboard_data_methods
import dashboard_data_viz
# Out:
# /anaconda/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Number of Users

# %%
dashboard_data_viz.Number_Of_Users()
# Out:
# 'Number of Users = 2165'

# %% [markdown]
# ## Number of Showed Menus

# %%
dashboard_data_viz.Number_Of_Interactions()
# Out:
# 'Number of Menus = 17184.0'

# %% [markdown]
# ## Number of Explored Options

# %%
dashboard_data_viz.Number_Of_Interactions2()
# Out:
# 'Number of Clicks = 10742'

# %% [markdown]
# ## Number of Likes

# %%
dashboard_data_viz.Number_Of_Likes()
# Out:
# 'Number of Likes = 3272'

# %% [markdown]
# ## Majors with more clicks

# %%
dashboard_data_viz.Top_10_ClickMajors()
# Out:
# Técnico Superior en Ciencias Aeronáuticas    501
# Ingeniería Eléctrica                         408
# Administración de Empresas                   351
# Contabilidad                                 327
# Ingeniería Industrial                        300
# Ingeniería Civil                             298
# Redes y Conectividad                         278
# Técnico Superior en Agrimensura              272
# Medicina                                     270
#  Diseño de Interiores                        247
# Name: Major_Name, dtype: int64

# %% [markdown]
# ## Majors with more likes

# %%
dashboard_data_viz.Top_10_LikesMajors()
# Out:
# Medicina                      148
# Ingeniería de Sistemas         99
# Psicología                     80
# Ingeniería Civil               79
# Contabilidad                   78
# Administración de Empresas     72
# Ingeniería Industrial          71
# Ingeniería de Computación      70
# Ciencias de la Educación       66
# Ingeniería del Software        64
# Name: Major_Name, dtype: int64

# %% [markdown]
# ## Number of Clicks By Areas

# %%
dashboard_data_viz.Clicks_by_Area()
# Out:
# INGENIERIA Y ARQUITECTURA                          2386
# NEGOCIOS                                           2014
# TECNOLOGIAS DE LA INFORMACION Y LA COMUNICACION    1259
# ARTES                                              1167
# SALUD                                              1147
# MILITAR                                             709
# EDUCACION                                           610
# HUMANIDADES                                         479
# CIENCIAS                                            392
# CIENCIAS ECONÓMICAS Y SOCIALES                      202
# CIENCIAS JURIDICAS Y POLITICAS                      192
# CIENCIAS AGROPECUARIAS Y VETERINARIA                104
# INTERNACIONAL                                        81
# Name: Area_Name, dtype: int64

# %% [markdown]
# ## Number of Likes By Areas

# %%
dashboard_data_viz.Likes_by_Area()
# Out:
# NEGOCIOS                                           613
# INGENIERIA Y ARQUITECTURA                          521
# TECNOLOGIAS DE LA INFORMACION Y LA COMUNICACION    490
# SALUD                                              410
# ARTES                                              360
# EDUCACION                                          257
# HUMANIDADES                                        217
# CIENCIAS                                           129
# CIENCIAS ECONÓMICAS Y SOCIALES                      84
# CIENCIAS JURIDICAS Y POLITICAS                      70
# MILITAR                                             58
# CIENCIAS AGROPECUARIAS Y VETERINARIA                35
# INTERNACIONAL                                       28
# Name: Area_Name, dtype: int64

# %% [markdown]
# ## Number of Users by Branch of Intervention

# %%
dashboard_data_viz.Number_Of_Users_by_Bot()

# %% [markdown]
# ## Number of Showed Menus by Branch of Intervention

# %%
dashboard_data_viz.Number_Of_Interactions_by_Bot()

# %% [markdown]
# ## Number of Interactions by Branch of Intervention

# %%
dashboard_data_viz.Number_Of_Interactions_by_Bot2()

# %% [markdown]
# ## Number of Clicks by Branch of Intervention

# %%
dashboard_data_viz.Number_Of_Clicks_by_Bot()

# %% [markdown]
# ## Ratio of Clicks over Displayed Options by Branch of Intervention

# %%
dashboard_data_viz.Clicks_over_Displayed_Options_by_Bot()

# %% [markdown]
# ## Number of Likes by Branch of Intervention

# %%
dashboard_data_viz.Number_Of_Likes_by_Bot()

# %% [markdown]
# ## Ratio of Likes over Displayed Options by Branch of Intervention

# %%
dashboard_data_viz.Likes_over_Displayed_Options_by_Bot()

# %% [markdown]
# ## Ratio of Likes over Clicks by branch of Intervention

# %%
dashboard_data_viz.Number_Of_Likes_Over_Explored_Options_by_Bot()

# %% [markdown]
# ## Percentage Of Clicked Options inside Areas of Interest of the Student

# %%
dashboard_data_viz.Number_of_ClickedOptions_in_Interest()

# %% [markdown]
# ## Percentage Of Liked Options inside Areas of Interest of the Student

# %%
dashboard_data_viz.Number_of_LikedOptions_in_Interest()

# %% [markdown]
# ## Wage Deviation by Number of Interactions

# %%
dashboard_data_viz.Wage_Deviation_by_Number_of_Interaction()

# %% [markdown]
# ## Distribution of Users' Math Score in Pruebas Nacionales

# %%
dashboard_data_viz.Histogram_MathScore()

# %% [markdown]
# ## Distribution of Users' Spanish Score in Pruebas Nacionales

# %%
dashboard_data_viz.Histogram_EspScore()

# %% [markdown]
# ## Number of Users by Sex

# %%
dashboard_data_viz.Females_Males()
